# %% [markdown]
# # CNN Model

# %%
import pandas as pd
import numpy as np

# %%
import yfinance as yf

ticker_symbol = 'NEE'

nee_data = yf.download(ticker_symbol, start='2013-01-01', end='2023-01-01')

print(nee_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059  8953200
# 2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911  4909200
# 2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745  3739200
# 2013-01-07  17.712500  17.735001  17.594999  17.637501  13.069619  5578400
# 2013-01-08  17.645000  17.825001  17.597500  17.825001  13.208551  7972400

# %%
nee_data.reset_index(inplace=True)

print(nee_data.head())
# Out:
#         Date       Open       High        Low      Close  Adj Close   Volume
# 0 2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059  8953200
# 1 2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911  4909200
# 2 2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745  3739200
# 3 2013-01-07  17.712500  17.735001  17.594999  17.637501  13.069619  5578400
# 4 2013-01-08  17.645000  17.825001  17.597500  17.825001  13.208551  7972400

# %%
nee_data['Date'] = pd.to_datetime(nee_data['Date'])
nee_data
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059
# 1    2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911
# 2    2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745
# 3    2013-01-07  17.712500  17.735001  17.594999  17.637501  13.069619
# 4    2013-01-08  17.645000  17.825001  17.597500  17.825001  13.208551
# ...         ...        ...        ...        ...        ...        ...
# 2513 2022-12-23  83.000000  84.269997  83.000000  84.169998  81.116180
# 2514 2022-12-27  84.099998  84.279999  83.470001  84.000000  80.952347
# 2515 2022-12-28  84.199997  84.540001  82.980003  83.160004  80.142830
# 2516 2022-12-29  83.730003  84.690002  83.489998  84.080002  81.029457
# 2517 2022-12-30  83.949997  84.019997  82.480003  83.599998  80.566872
#
#        Volume
# 0     8953200
# 1     4909200
# 2     3739200
# 3     5578400
# 4     7972400
# ...       ...
# 2513  3254700
# 2514  4726500
# 2515  3536400
# 2516  3378300
# 2517  4266900
#
# [2518 rows x 7 columns]

# %%
date_range_start = '2013-01-01'
date_range_end = '2023-01-01'
full_date_range = pd.date_range(start=date_range_start, end=date_range_end)
date_range_df = pd.DataFrame(full_date_range, columns=['Date'])
nee_merged = pd.merge(date_range_df, nee_data, on='Date', how='left')
nee_merged
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-01        NaN        NaN        NaN        NaN        NaN
# 1    2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059
# 2    2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911
# 3    2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745
# 4    2013-01-05        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 3648 2022-12-28  84.199997  84.540001  82.980003  83.160004  80.142830
# 3649 2022-12-29  83.730003  84.690002  83.489998  84.080002  81.029457
# 3650 2022-12-30  83.949997  84.019997  82.480003  83.599998  80.566872
# 3651 2022-12-31        NaN        NaN        NaN        NaN        NaN
# 3652 2023-01-01        NaN        NaN        NaN        NaN        NaN
#
#          Volume
# 0           NaN
# 1     8953200.0
# 2     4909200.0
# 3     3739200.0
# 4           NaN
# ...         ...
# 3648  3536400.0
# 3649  3378300.0
# 3650  4266900.0
# 3651        NaN
# 3652        NaN
#
# [3653 rows x 7 columns]

# %%
financial_metrics = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
for metric in financial_metrics:
    nee_merged[metric].interpolate(method='linear', inplace=True)

nee_merged.bfill(inplace=True)
nee_merged
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-01  17.497499  17.642500  17.452499  17.629999  13.064059
# 1    2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059
# 2    2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911
# 3    2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745
# 4    2013-01-05  17.677500  17.736666  17.606666  17.692500  13.110370
# ...         ...        ...        ...        ...        ...        ...
# 3648 2022-12-28  84.199997  84.540001  82.980003  83.160004  80.142830
# 3649 2022-12-29  83.730003  84.690002  83.489998  84.080002  81.029457
# 3650 2022-12-30  83.949997  84.019997  82.480003  83.599998  80.566872
# 3651 2022-12-31  83.949997  84.019997  82.480003  83.599998  80.566872
# 3652 2023-01-01  83.949997  84.019997  82.480003  83.599998  80.566872
#
#             Volume
# 0     8.953200e+06
# 1     8.953200e+06
# 2     4.909200e+06
# 3     3.739200e+06
# 4     4.352267e+06
# ...            ...
# 3648  3.536400e+06
# 3649  3.378300e+06
# 3650  4.266900e+06
# 3651  4.266900e+06
# 3652  4.266900e+06
#
# [3653 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 7))
plt.plot(nee_merged['Close'], label='Close Price', color='blue')
plt.title('NextEra Energy Inc Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

data = nee_merged[['Close']].values

scaler = MinMaxScaler(feature_range=(0,1))
data_scaled = scaler.fit_transform(data)

def create_sequences(data, sequence_length):
    xs, ys = [], []
    for i in range(len(data)-sequence_length):
        x = data[i:(i+sequence_length)]
        y = data[i+sequence_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

sequence_length = 10
X, y = create_sequences(data_scaled, sequence_length)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3278, 10, 1)
# (365, 10, 1)
# (3278, 1)
# (365, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam

model = Sequential()

model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1],X_train.shape[2]), padding='same'))
model.add(MaxPooling1D(pool_size=1, padding='same'))
# Flatten the convolution output to feed it into a dense layer
model.add(Flatten())
# Output layer
model.add(Dense(units=1))   # Assuming a regression problem

model.compile(optimizer = 'adam', loss = 'mse' , metrics=['mean_absolute_error'])

# Print the model summary to review its architecture
model.summary()
# Out:
# C:\Users\Timch\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 10, 32)              │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 10, 32)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 320)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             321 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 449 (1.75 KB)
#  Trainable params: 449 (1.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, validation_split=0.1)
# Out:
# Epoch 1/50
# 47/47 - 1s - 26ms/step - loss: 0.0127 - mean_absolute_error: 0.0684 - val_loss: 0.0039 - val_mean_absolute_error: 0.0545
# Epoch 2/50
# 47/47 - 0s - 2ms/step - loss: 1.9857e-04 - mean_absolute_error: 0.0087 - val_loss: 4.2332e-04 - val_mean_absolute_error: 0.0167
# Epoch 3/50
# 47/47 - 0s - 2ms/step - loss: 1.6326e-04 - mean_absolute_error: 0.0070 - val_loss: 4.1697e-04 - val_mean_absolute_error: 0.0168
# Epoch 4/50
# 47/47 - 0s - 2ms/step - loss: 1.5968e-04 - mean_absolute_error: 0.0069 - val_loss: 3.9969e-04 - val_mean_absolute_error: 0.0164
# Epoch 5/50
# 47/47 - 0s - 2ms/step - loss: 1.5849e-04 - mean_absolute_error: 0.0068 - val_loss: 3.8258e-04 - val_mean_absolute_error: 0.0160
# Epoch 6/50
# 47/47 - 0s - 3ms/step - loss: 1.5916e-04 - mean_absolute_error: 0.0069 - val_loss: 3.8163e-04 - val_mean_absolute_error: 0.0159
# Epoch 7/50
# 47/47 - 0s - 3ms/step - loss: 1.5567e-04 - mean_absolute_error: 0.0068 - val_loss: 3.7173e-04 - val_mean_absolute_error: 0.0158
# Epoch 8/50
# 47/47 - 0s - 3ms/step - loss: 1.5585e-04 - mean_absolute_error: 0.0068 - val_loss: 3.7905e-04 - val_mean_absolute_error: 0.0158
# Epoch 9/50
# 47/47 - 0s - 2ms/step - loss: 1.5328e-04 - mean_absolute_error: 0.0068 - val_loss: 3.5970e-04 - val_mean_absolute_error: 0.0155
# Epoch 10/50
# 47/47 - 0s - 2ms/step - loss: 1.5383e-04 - mean_absolute_error: 0.0070 - val_loss: 3.5385e-04 - val_mean_absolute_error: 0.0154
# Epoch 11/50
# 47/47 - 0s - 2ms/step - loss: 1.4286e-04 - mean_absolute_error: 0.0066 - val_loss: 3.4700e-04 - val_mean_absolute_error: 0.0152
# Epoch 12/50
# 47/47 - 0s - 2ms/step - loss: 1.4693e-04 - mean_absolute_error: 0.0067 - val_loss: 3.7203e-04 - val_mean_absolute_error: 0.0159
# Epoch 13/50
# 47/47 - 0s - 3ms/step - loss: 1.4149e-04 - mean_absolute_error: 0.0064 - val_loss: 3.7664e-04 - val_mean_absolute_error: 0.0157
# Epoch 14/50
# 47/47 - 0s - 2ms/step - loss: 1.4143e-04 - mean_absolute_error: 0.0065 - val_loss: 3.6463e-04 - val_mean_absolute_error: 0.0157
# Epoch 15/50
# 47/47 - 0s - 3ms/step - loss: 1.3713e-04 - mean_absolute_error: 0.0064 - val_loss: 3.2039e-04 - val_mean_absolute_error: 0.0145
# Epoch 16/50
# 47/47 - 0s - 3ms/step - loss: 1.4013e-04 - mean_absolute_error: 0.0068 - val_loss: 3.2259e-04 - val_mean_absolute_error: 0.0145
# Epoch 17/50
# 47/47 - 0s - 3ms/step - loss: 1.2963e-04 - mean_absolute_error: 0.0063 - val_loss: 3.0794e-04 - val_mean_absolute_error: 0.0142
# Epoch 18/50
# 47/47 - 0s - 3ms/step - loss: 1.3020e-04 - mean_absolute_error: 0.0064 - val_loss: 3.3524e-04 - val_mean_absolute_error: 0.0147
# Epoch 19/50
# 47/47 - 0s - 3ms/step - loss: 1.2260e-04 - mean_absolute_error: 0.0060 - val_loss: 3.7654e-04 - val_mean_absolute_error: 0.0156
# Epoch 20/50
# 47/47 - 0s - 3ms/step - loss: 1.2239e-04 - mean_absolute_error: 0.0061 - val_loss: 2.9352e-04 - val_mean_absolute_error: 0.0137
# Epoch 21/50
# 47/47 - 0s - 3ms/step - loss: 1.1787e-04 - mean_absolute_error: 0.0060 - val_loss: 2.8488e-04 - val_mean_absolute_error: 0.0135
# Epoch 22/50
# 47/47 - 0s - 3ms/step - loss: 1.1541e-04 - mean_absolute_error: 0.0059 - val_loss: 2.7853e-04 - val_mean_absolute_error: 0.0133
# Epoch 23/50
# 47/47 - 0s - 3ms/step - loss: 1.1624e-04 - mean_absolute_error: 0.0061 - val_loss: 2.8215e-04 - val_mean_absolute_error: 0.0135
# Epoch 24/50
# 47/47 - 0s - 3ms/step - loss: 1.1690e-04 - mean_absolute_error: 0.0063 - val_loss: 2.6358e-04 - val_mean_absolute_error: 0.0130
# Epoch 25/50
# 47/47 - 0s - 3ms/step - loss: 1.0720e-04 - mean_absolute_error: 0.0058 - val_loss: 2.7962e-04 - val_mean_absolute_error: 0.0133
# Epoch 26/50
# 47/47 - 0s - 3ms/step - loss: 1.0345e-04 - mean_absolute_error: 0.0056 - val_loss: 2.4280e-04 - val_mean_absolute_error: 0.0124
# Epoch 27/50
# 47/47 - 0s - 3ms/step - loss: 1.0123e-04 - mean_absolute_error: 0.0057 - val_loss: 2.3700e-04 - val_mean_absolute_error: 0.0122
# Epoch 28/50
# 47/47 - 0s - 3ms/step - loss: 9.7614e-05 - mean_absolute_error: 0.0055 - val_loss: 2.5640e-04 - val_mean_absolute_error: 0.0128
# Epoch 29/50
# 47/47 - 0s - 3ms/step - loss: 9.9687e-05 - mean_absolute_error: 0.0055 - val_loss: 2.8920e-04 - val_mean_absolute_error: 0.0135
# Epoch 30/50
# 47/47 - 0s - 3ms/step - loss: 9.6000e-05 - mean_absolute_error: 0.0056 - val_loss: 2.3152e-04 - val_mean_absolute_error: 0.0121
# Epoch 31/50
# 47/47 - 0s - 3ms/step - loss: 9.0294e-05 - mean_absolute_error: 0.0053 - val_loss: 2.7221e-04 - val_mean_absolute_error: 0.0130
# Epoch 32/50
# 47/47 - 0s - 4ms/step - loss: 8.6830e-05 - mean_absolute_error: 0.0051 - val_loss: 2.1834e-04 - val_mean_absolute_error: 0.0117
# Epoch 33/50
# 47/47 - 0s - 2ms/step - loss: 8.4079e-05 - mean_absolute_error: 0.0050 - val_loss: 2.0496e-04 - val_mean_absolute_error: 0.0112
# Epoch 34/50
# 47/47 - 0s - 2ms/step - loss: 8.9490e-05 - mean_absolute_error: 0.0050 - val_loss: 4.7011e-04 - val_mean_absolute_error: 0.0175
# Epoch 35/50
# 47/47 - 0s - 3ms/step - loss: 1.0209e-04 - mean_absolute_error: 0.0061 - val_loss: 2.4998e-04 - val_mean_absolute_error: 0.0123
# Epoch 36/50
# 47/47 - 0s - 3ms/step - loss: 8.6336e-05 - mean_absolute_error: 0.0052 - val_loss: 3.4052e-04 - val_mean_absolute_error: 0.0156
# Epoch 37/50
# 47/47 - 0s - 3ms/step - loss: 8.6698e-05 - mean_absolute_error: 0.0056 - val_loss: 1.8276e-04 - val_mean_absolute_error: 0.0106
# Epoch 38/50
# 47/47 - 0s - 3ms/step - loss: 8.0924e-05 - mean_absolute_error: 0.0049 - val_loss: 2.2143e-04 - val_mean_absolute_error: 0.0120
# Epoch 39/50
# 47/47 - 0s - 3ms/step - loss: 8.2714e-05 - mean_absolute_error: 0.0053 - val_loss: 2.1269e-04 - val_mean_absolute_error: 0.0113
# Epoch 40/50
# 47/47 - 0s - 3ms/step - loss: 8.1538e-05 - mean_absolute_error: 0.0052 - val_loss: 3.2151e-04 - val_mean_absolute_error: 0.0142
# Epoch 41/50
# 47/47 - 0s - 3ms/step - loss: 7.9583e-05 - mean_absolute_error: 0.0051 - val_loss: 1.7391e-04 - val_mean_absolute_error: 0.0102
# Epoch 42/50
# 47/47 - 0s - 3ms/step - loss: 7.2916e-05 - mean_absolute_error: 0.0048 - val_loss: 1.6191e-04 - val_mean_absolute_error: 0.0099
# Epoch 43/50
# 47/47 - 0s - 2ms/step - loss: 7.0443e-05 - mean_absolute_error: 0.0047 - val_loss: 1.6045e-04 - val_mean_absolute_error: 0.0098
# Epoch 44/50
# 47/47 - 0s - 2ms/step - loss: 6.9328e-05 - mean_absolute_error: 0.0046 - val_loss: 1.6703e-04 - val_mean_absolute_error: 0.0099
# Epoch 45/50
# 47/47 - 0s - 2ms/step - loss: 6.7992e-05 - mean_absolute_error: 0.0047 - val_loss: 1.6360e-04 - val_mean_absolute_error: 0.0097
# Epoch 46/50
# 47/47 - 0s - 3ms/step - loss: 6.7758e-05 - mean_absolute_error: 0.0045 - val_loss: 1.6881e-04 - val_mean_absolute_error: 0.0098
# Epoch 47/50
# 47/47 - 0s - 2ms/step - loss: 7.0173e-05 - mean_absolute_error: 0.0046 - val_loss: 3.7651e-04 - val_mean_absolute_error: 0.0157
# Epoch 48/50
# 47/47 - 0s - 2ms/step - loss: 6.5674e-05 - mean_absolute_error: 0.0046 - val_loss: 1.4811e-04 - val_mean_absolute_error: 0.0092
# Epoch 49/50
# 47/47 - 0s - 3ms/step - loss: 6.4061e-05 - mean_absolute_error: 0.0044 - val_loss: 1.5047e-04 - val_mean_absolute_error: 0.0096
# Epoch 50/50
# 47/47 - 0s - 3ms/step - loss: 6.4559e-05 - mean_absolute_error: 0.0046 - val_loss: 1.5707e-04 - val_mean_absolute_error: 0.0094

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training Loss vs. Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred_actual = scaler.inverse_transform(train_pred)
train_actual = scaler.inverse_transform(y_train)
test_pred_actual = scaler.inverse_transform(test_pred)
test_actual = scaler.inverse_transform(y_test)

train_rmse = sqrt(mean_squared_error(train_actual, train_pred_actual))
train_mae = mean_absolute_error(train_actual, train_pred_actual)
train_mape = np.mean(np.abs((train_actual - train_pred_actual) / train_actual)) * 100

test_rmse = sqrt(mean_squared_error(test_actual, test_pred_actual))
test_mae = mean_absolute_error(test_actual, test_pred_actual)
test_mape = np.mean(np.abs((test_actual - test_pred_actual) / test_actual)) * 100

print('Train RMSE:', train_rmse)
print('Train MAE:', train_mae)
print('Train MAPE:', train_mape)
print('Test RMSE:', test_rmse)
print('Test MAE:', test_mae)
print('Test MAPE:', test_mape)
# Out:
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Train RMSE: 0.6361410035315102
# Train MAE: 0.3565782863530828
# Train MAPE: 0.7963097838577525
# Test RMSE: 1.4445561615385116
# Test MAE: 1.053526658010265
# Test MAPE: 1.3233807577368102

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(train_actual, label='Actual')
plt.plot(train_pred_actual, label='Predicted')
plt.title('Training Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()

plt.subplot(1,2,2)
plt.plot(test_actual, label='Actual')
plt.plot(test_pred_actual, label='Predicted')
plt.title('Testing Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

train_time = range(len(train_actual))
test_time = range(len(train_actual), len(train_actual) + len(test_actual))

plt.figure(figsize=(15, 7))
plt.plot(train_time, train_actual, label='Actual Train', color='blue')
plt.plot(train_time, train_pred_actual, label='Predicted Train', color='orange', alpha=0.7)
plt.plot(test_time, test_actual, label='Actual Test', color='green')
plt.plot(test_time, test_pred_actual, label='Predicted Test', color='red', alpha=0.7)

plt.title('Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %% [markdown]
# # LSTM Model

# %%
import pandas as pd
import numpy as np

# %%
import yfinance as yf

ticker_symbol = 'NEE'

nee_data = yf.download(ticker_symbol, start='2013-01-01', end='2023-01-01')

print(nee_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059  8953200
# 2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911  4909200
# 2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745  3739200
# 2013-01-07  17.712500  17.735001  17.594999  17.637501  13.069619  5578400
# 2013-01-08  17.645000  17.825001  17.597500  17.825001  13.208551  7972400

# %%
nee_data.reset_index(inplace=True)

print(nee_data.head())
# Out:
#         Date       Open       High        Low      Close  Adj Close   Volume
# 0 2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059  8953200
# 1 2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911  4909200
# 2 2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745  3739200
# 3 2013-01-07  17.712500  17.735001  17.594999  17.637501  13.069619  5578400
# 4 2013-01-08  17.645000  17.825001  17.597500  17.825001  13.208551  7972400

# %%
nee_data['Date'] = pd.to_datetime(nee_data['Date'])
nee_data
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059
# 1    2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911
# 2    2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745
# 3    2013-01-07  17.712500  17.735001  17.594999  17.637501  13.069619
# 4    2013-01-08  17.645000  17.825001  17.597500  17.825001  13.208551
# ...         ...        ...        ...        ...        ...        ...
# 2513 2022-12-23  83.000000  84.269997  83.000000  84.169998  81.116180
# 2514 2022-12-27  84.099998  84.279999  83.470001  84.000000  80.952347
# 2515 2022-12-28  84.199997  84.540001  82.980003  83.160004  80.142830
# 2516 2022-12-29  83.730003  84.690002  83.489998  84.080002  81.029457
# 2517 2022-12-30  83.949997  84.019997  82.480003  83.599998  80.566872
#
#        Volume
# 0     8953200
# 1     4909200
# 2     3739200
# 3     5578400
# 4     7972400
# ...       ...
# 2513  3254700
# 2514  4726500
# 2515  3536400
# 2516  3378300
# 2517  4266900
#
# [2518 rows x 7 columns]

# %%
date_range_start = '2013-01-01'
date_range_end = '2023-01-01'
full_date_range = pd.date_range(start=date_range_start, end=date_range_end)
date_range_df = pd.DataFrame(full_date_range, columns=['Date'])
nee_merged = pd.merge(date_range_df, nee_data, on='Date', how='left')
nee_merged
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-01        NaN        NaN        NaN        NaN        NaN
# 1    2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059
# 2    2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911
# 3    2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745
# 4    2013-01-05        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 3648 2022-12-28  84.199997  84.540001  82.980003  83.160004  80.142830
# 3649 2022-12-29  83.730003  84.690002  83.489998  84.080002  81.029457
# 3650 2022-12-30  83.949997  84.019997  82.480003  83.599998  80.566872
# 3651 2022-12-31        NaN        NaN        NaN        NaN        NaN
# 3652 2023-01-01        NaN        NaN        NaN        NaN        NaN
#
#          Volume
# 0           NaN
# 1     8953200.0
# 2     4909200.0
# 3     3739200.0
# 4           NaN
# ...         ...
# 3648  3536400.0
# 3649  3378300.0
# 3650  4266900.0
# 3651        NaN
# 3652        NaN
#
# [3653 rows x 7 columns]

# %%
financial_metrics = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
for metric in financial_metrics:
    nee_merged[metric].interpolate(method='linear', inplace=True)

nee_merged.bfill(inplace=True)
nee_merged
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-01  17.497499  17.642500  17.452499  17.629999  13.064059
# 1    2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059
# 2    2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911
# 3    2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745
# 4    2013-01-05  17.677500  17.736666  17.606666  17.692500  13.110370
# ...         ...        ...        ...        ...        ...        ...
# 3648 2022-12-28  84.199997  84.540001  82.980003  83.160004  80.142830
# 3649 2022-12-29  83.730003  84.690002  83.489998  84.080002  81.029457
# 3650 2022-12-30  83.949997  84.019997  82.480003  83.599998  80.566872
# 3651 2022-12-31  83.949997  84.019997  82.480003  83.599998  80.566872
# 3652 2023-01-01  83.949997  84.019997  82.480003  83.599998  80.566872
#
#             Volume
# 0     8.953200e+06
# 1     8.953200e+06
# 2     4.909200e+06
# 3     3.739200e+06
# 4     4.352267e+06
# ...            ...
# 3648  3.536400e+06
# 3649  3.378300e+06
# 3650  4.266900e+06
# 3651  4.266900e+06
# 3652  4.266900e+06
#
# [3653 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 7))
plt.plot(nee_merged['Close'], label='Close Price', color='blue')
plt.title('NextEra Energy Inc Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

data = nee_merged[['Close']].values

scaler = MinMaxScaler(feature_range=(0,1))
data_scaled = scaler.fit_transform(data)

def create_sequences(data, sequence_length):
    xs, ys = [], []
    for i in range(len(data)-sequence_length):
        x = data[i:(i+sequence_length)]
        y = data[i+sequence_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

sequence_length = 10
X, y = create_sequences(data_scaled, sequence_length)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3278, 10, 1)
# (365, 10, 1)
# (3278, 1)
# (365, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

model = Sequential()

model.add(LSTM(units=64, activation='tanh', input_shape=(X_train.shape[1],X_train.shape[2]), return_sequences=False))
model.add(Dense(units = 1))

model.compile(optimizer = 'adam', loss = 'mse' , metrics=['mean_absolute_error'])
model.summary()
# Out:
# C:\Users\Timch\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, validation_split=0.1)
# Out:
# Epoch 1/50
# 47/47 - 3s - 72ms/step - loss: 0.0234 - mean_absolute_error: 0.0957 - val_loss: 8.3010e-04 - val_mean_absolute_error: 0.0232
# Epoch 2/50
# 47/47 - 0s - 6ms/step - loss: 3.1437e-04 - mean_absolute_error: 0.0124 - val_loss: 6.7874e-04 - val_mean_absolute_error: 0.0207
# Epoch 3/50
# 47/47 - 0s - 6ms/step - loss: 2.1667e-04 - mean_absolute_error: 0.0096 - val_loss: 5.8751e-04 - val_mean_absolute_error: 0.0193
# Epoch 4/50
# 47/47 - 0s - 5ms/step - loss: 1.9672e-04 - mean_absolute_error: 0.0085 - val_loss: 5.9846e-04 - val_mean_absolute_error: 0.0195
# Epoch 5/50
# 47/47 - 0s - 5ms/step - loss: 1.8327e-04 - mean_absolute_error: 0.0079 - val_loss: 4.6799e-04 - val_mean_absolute_error: 0.0174
# Epoch 6/50
# 47/47 - 0s - 5ms/step - loss: 1.8156e-04 - mean_absolute_error: 0.0076 - val_loss: 4.4798e-04 - val_mean_absolute_error: 0.0170
# Epoch 7/50
# 47/47 - 0s - 5ms/step - loss: 1.8101e-04 - mean_absolute_error: 0.0075 - val_loss: 5.4558e-04 - val_mean_absolute_error: 0.0185
# Epoch 8/50
# 47/47 - 0s - 5ms/step - loss: 1.7575e-04 - mean_absolute_error: 0.0074 - val_loss: 5.2204e-04 - val_mean_absolute_error: 0.0180
# Epoch 9/50
# 47/47 - 0s - 5ms/step - loss: 1.7298e-04 - mean_absolute_error: 0.0072 - val_loss: 5.4387e-04 - val_mean_absolute_error: 0.0183
# Epoch 10/50
# 47/47 - 0s - 5ms/step - loss: 1.7271e-04 - mean_absolute_error: 0.0073 - val_loss: 4.5570e-04 - val_mean_absolute_error: 0.0169
# Epoch 11/50
# 47/47 - 0s - 5ms/step - loss: 1.7471e-04 - mean_absolute_error: 0.0075 - val_loss: 5.2745e-04 - val_mean_absolute_error: 0.0183
# Epoch 12/50
# 47/47 - 0s - 5ms/step - loss: 1.6999e-04 - mean_absolute_error: 0.0073 - val_loss: 4.5125e-04 - val_mean_absolute_error: 0.0168
# Epoch 13/50
# 47/47 - 0s - 5ms/step - loss: 1.6916e-04 - mean_absolute_error: 0.0070 - val_loss: 5.7661e-04 - val_mean_absolute_error: 0.0189
# Epoch 14/50
# 47/47 - 0s - 5ms/step - loss: 1.6889e-04 - mean_absolute_error: 0.0072 - val_loss: 4.6840e-04 - val_mean_absolute_error: 0.0170
# Epoch 15/50
# 47/47 - 0s - 6ms/step - loss: 1.6257e-04 - mean_absolute_error: 0.0071 - val_loss: 4.3452e-04 - val_mean_absolute_error: 0.0165
# Epoch 16/50
# 47/47 - 0s - 5ms/step - loss: 1.6463e-04 - mean_absolute_error: 0.0070 - val_loss: 5.8307e-04 - val_mean_absolute_error: 0.0190
# Epoch 17/50
# 47/47 - 0s - 6ms/step - loss: 1.6958e-04 - mean_absolute_error: 0.0072 - val_loss: 5.0192e-04 - val_mean_absolute_error: 0.0176
# Epoch 18/50
# 47/47 - 0s - 7ms/step - loss: 1.6726e-04 - mean_absolute_error: 0.0073 - val_loss: 7.6949e-04 - val_mean_absolute_error: 0.0220
# Epoch 19/50
# 47/47 - 0s - 7ms/step - loss: 1.5684e-04 - mean_absolute_error: 0.0070 - val_loss: 4.0864e-04 - val_mean_absolute_error: 0.0161
# Epoch 20/50
# 47/47 - 0s - 8ms/step - loss: 1.5812e-04 - mean_absolute_error: 0.0069 - val_loss: 5.9468e-04 - val_mean_absolute_error: 0.0192
# Epoch 21/50
# 47/47 - 0s - 7ms/step - loss: 1.6409e-04 - mean_absolute_error: 0.0072 - val_loss: 3.9530e-04 - val_mean_absolute_error: 0.0158
# Epoch 22/50
# 47/47 - 0s - 7ms/step - loss: 1.5314e-04 - mean_absolute_error: 0.0068 - val_loss: 7.0122e-04 - val_mean_absolute_error: 0.0210
# Epoch 23/50
# 47/47 - 0s - 9ms/step - loss: 1.6089e-04 - mean_absolute_error: 0.0071 - val_loss: 4.6353e-04 - val_mean_absolute_error: 0.0170
# Epoch 24/50
# 47/47 - 0s - 6ms/step - loss: 1.5075e-04 - mean_absolute_error: 0.0068 - val_loss: 3.9025e-04 - val_mean_absolute_error: 0.0157
# Epoch 25/50
# 47/47 - 0s - 5ms/step - loss: 1.5795e-04 - mean_absolute_error: 0.0071 - val_loss: 3.7169e-04 - val_mean_absolute_error: 0.0153
# Epoch 26/50
# 47/47 - 0s - 6ms/step - loss: 1.4904e-04 - mean_absolute_error: 0.0067 - val_loss: 4.0567e-04 - val_mean_absolute_error: 0.0161
# Epoch 27/50
# 47/47 - 0s - 7ms/step - loss: 1.5522e-04 - mean_absolute_error: 0.0071 - val_loss: 4.9168e-04 - val_mean_absolute_error: 0.0179
# Epoch 28/50
# 47/47 - 0s - 6ms/step - loss: 1.5462e-04 - mean_absolute_error: 0.0069 - val_loss: 3.7938e-04 - val_mean_absolute_error: 0.0154
# Epoch 29/50
# 47/47 - 0s - 6ms/step - loss: 1.5048e-04 - mean_absolute_error: 0.0070 - val_loss: 3.8932e-04 - val_mean_absolute_error: 0.0156
# Epoch 30/50
# 47/47 - 0s - 6ms/step - loss: 1.4104e-04 - mean_absolute_error: 0.0066 - val_loss: 3.4345e-04 - val_mean_absolute_error: 0.0147
# Epoch 31/50
# 47/47 - 0s - 6ms/step - loss: 1.5828e-04 - mean_absolute_error: 0.0073 - val_loss: 5.6552e-04 - val_mean_absolute_error: 0.0189
# Epoch 32/50
# 47/47 - 0s - 6ms/step - loss: 1.4310e-04 - mean_absolute_error: 0.0068 - val_loss: 3.3305e-04 - val_mean_absolute_error: 0.0145
# Epoch 33/50
# 47/47 - 0s - 6ms/step - loss: 1.3349e-04 - mean_absolute_error: 0.0065 - val_loss: 3.2508e-04 - val_mean_absolute_error: 0.0143
# Epoch 34/50
# 47/47 - 0s - 5ms/step - loss: 1.3251e-04 - mean_absolute_error: 0.0064 - val_loss: 3.1783e-04 - val_mean_absolute_error: 0.0141
# Epoch 35/50
# 47/47 - 0s - 5ms/step - loss: 1.3288e-04 - mean_absolute_error: 0.0064 - val_loss: 3.2486e-04 - val_mean_absolute_error: 0.0143
# Epoch 36/50
# 47/47 - 0s - 5ms/step - loss: 1.3938e-04 - mean_absolute_error: 0.0065 - val_loss: 3.4916e-04 - val_mean_absolute_error: 0.0150
# Epoch 37/50
# 47/47 - 0s - 7ms/step - loss: 1.4458e-04 - mean_absolute_error: 0.0069 - val_loss: 3.1290e-04 - val_mean_absolute_error: 0.0140
# Epoch 38/50
# 47/47 - 0s - 6ms/step - loss: 1.3483e-04 - mean_absolute_error: 0.0065 - val_loss: 3.1217e-04 - val_mean_absolute_error: 0.0141
# Epoch 39/50
# 47/47 - 0s - 7ms/step - loss: 1.2832e-04 - mean_absolute_error: 0.0065 - val_loss: 3.3242e-04 - val_mean_absolute_error: 0.0143
# Epoch 40/50
# 47/47 - 0s - 7ms/step - loss: 1.3291e-04 - mean_absolute_error: 0.0065 - val_loss: 3.0591e-04 - val_mean_absolute_error: 0.0139
# Epoch 41/50
# 47/47 - 1s - 13ms/step - loss: 1.3478e-04 - mean_absolute_error: 0.0070 - val_loss: 6.9274e-04 - val_mean_absolute_error: 0.0229
# Epoch 42/50
# 47/47 - 0s - 5ms/step - loss: 1.3392e-04 - mean_absolute_error: 0.0067 - val_loss: 3.1099e-04 - val_mean_absolute_error: 0.0137
# Epoch 43/50
# 47/47 - 0s - 5ms/step - loss: 1.2302e-04 - mean_absolute_error: 0.0063 - val_loss: 3.4811e-04 - val_mean_absolute_error: 0.0145
# Epoch 44/50
# 47/47 - 0s - 6ms/step - loss: 1.2026e-04 - mean_absolute_error: 0.0061 - val_loss: 3.3745e-04 - val_mean_absolute_error: 0.0143
# Epoch 45/50
# 47/47 - 0s - 6ms/step - loss: 1.1572e-04 - mean_absolute_error: 0.0061 - val_loss: 3.3413e-04 - val_mean_absolute_error: 0.0142
# Epoch 46/50
# 47/47 - 0s - 6ms/step - loss: 1.1563e-04 - mean_absolute_error: 0.0060 - val_loss: 2.6186e-04 - val_mean_absolute_error: 0.0126
# Epoch 47/50
# 47/47 - 0s - 6ms/step - loss: 1.2844e-04 - mean_absolute_error: 0.0063 - val_loss: 2.5434e-04 - val_mean_absolute_error: 0.0126
# Epoch 48/50
# 47/47 - 0s - 6ms/step - loss: 1.1956e-04 - mean_absolute_error: 0.0062 - val_loss: 2.4586e-04 - val_mean_absolute_error: 0.0123
# Epoch 49/50
# 47/47 - 0s - 6ms/step - loss: 1.1778e-04 - mean_absolute_error: 0.0063 - val_loss: 2.4088e-04 - val_mean_absolute_error: 0.0122
# Epoch 50/50
# 47/47 - 0s - 6ms/step - loss: 1.1646e-04 - mean_absolute_error: 0.0061 - val_loss: 2.3869e-04 - val_mean_absolute_error: 0.0120

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training Loss vs. Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred_actual = scaler.inverse_transform(train_pred)
train_actual = scaler.inverse_transform(y_train)
test_pred_actual = scaler.inverse_transform(test_pred)
test_actual = scaler.inverse_transform(y_test)

train_rmse = sqrt(mean_squared_error(train_actual, train_pred_actual))
train_mae = mean_absolute_error(train_actual, train_pred_actual)
train_mape = np.mean(np.abs((train_actual - train_pred_actual) / train_actual)) * 100

test_rmse = sqrt(mean_squared_error(test_actual, test_pred_actual))
test_mae = mean_absolute_error(test_actual, test_pred_actual)
test_mape = np.mean(np.abs((test_actual - test_pred_actual) / test_actual)) * 100

print('Train RMSE:', train_rmse)
print('Train MAE:', train_mae)
print('Train MAPE:', train_mape)
print('Test RMSE:', test_rmse)
print('Test MAE:', test_mae)
print('Test MAPE:', test_mape)
# Out:
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Train RMSE: 0.8281953379947506
# Train MAE: 0.46947629979792865
# Train MAPE: 1.0773264094428725
# Test RMSE: 1.8858934613733915
# Test MAE: 1.403951155431739
# Test MAPE: 1.7713979427313724

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(train_actual, label='Actual')
plt.plot(train_pred_actual, label='Predicted')
plt.title('Training Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()

plt.subplot(1,2,2)
plt.plot(test_actual, label='Actual')
plt.plot(test_pred_actual, label='Predicted')
plt.title('Testing Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

train_time = range(len(train_actual))
test_time = range(len(train_actual), len(train_actual) + len(test_actual))

plt.figure(figsize=(15, 7))
plt.plot(train_time, train_actual, label='Actual Train', color='blue')
plt.plot(train_time, train_pred_actual, label='Predicted Train', color='orange', alpha=0.7)
plt.plot(test_time, test_actual, label='Actual Test', color='green')
plt.plot(test_time, test_pred_actual, label='Predicted Test', color='red', alpha=0.7)

plt.title('Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %% [markdown]
# # CNN-LSTM Model

# %%
import pandas as pd
import numpy as np

# %%
import yfinance as yf

ticker_symbol = 'NEE'

nee_data = yf.download(ticker_symbol, start='2013-01-01', end='2023-01-01')

print(nee_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059  8953200
# 2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911  4909200
# 2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745  3739200
# 2013-01-07  17.712500  17.735001  17.594999  17.637501  13.069619  5578400
# 2013-01-08  17.645000  17.825001  17.597500  17.825001  13.208551  7972400

# %%
nee_data.reset_index(inplace=True)

print(nee_data.head())
# Out:
#         Date       Open       High        Low      Close  Adj Close   Volume
# 0 2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059  8953200
# 1 2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911  4909200
# 2 2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745  3739200
# 3 2013-01-07  17.712500  17.735001  17.594999  17.637501  13.069619  5578400
# 4 2013-01-08  17.645000  17.825001  17.597500  17.825001  13.208551  7972400

# %%
nee_data['Date'] = pd.to_datetime(nee_data['Date'])
nee_data
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059
# 1    2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911
# 2    2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745
# 3    2013-01-07  17.712500  17.735001  17.594999  17.637501  13.069619
# 4    2013-01-08  17.645000  17.825001  17.597500  17.825001  13.208551
# ...         ...        ...        ...        ...        ...        ...
# 2513 2022-12-23  83.000000  84.269997  83.000000  84.169998  81.116180
# 2514 2022-12-27  84.099998  84.279999  83.470001  84.000000  80.952347
# 2515 2022-12-28  84.199997  84.540001  82.980003  83.160004  80.142830
# 2516 2022-12-29  83.730003  84.690002  83.489998  84.080002  81.029457
# 2517 2022-12-30  83.949997  84.019997  82.480003  83.599998  80.566872
#
#        Volume
# 0     8953200
# 1     4909200
# 2     3739200
# 3     5578400
# 4     7972400
# ...       ...
# 2513  3254700
# 2514  4726500
# 2515  3536400
# 2516  3378300
# 2517  4266900
#
# [2518 rows x 7 columns]

# %%
date_range_start = '2013-01-01'
date_range_end = '2023-01-01'
full_date_range = pd.date_range(start=date_range_start, end=date_range_end)
date_range_df = pd.DataFrame(full_date_range, columns=['Date'])
nee_merged = pd.merge(date_range_df, nee_data, on='Date', how='left')
nee_merged
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-01        NaN        NaN        NaN        NaN        NaN
# 1    2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059
# 2    2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911
# 3    2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745
# 4    2013-01-05        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 3648 2022-12-28  84.199997  84.540001  82.980003  83.160004  80.142830
# 3649 2022-12-29  83.730003  84.690002  83.489998  84.080002  81.029457
# 3650 2022-12-30  83.949997  84.019997  82.480003  83.599998  80.566872
# 3651 2022-12-31        NaN        NaN        NaN        NaN        NaN
# 3652 2023-01-01        NaN        NaN        NaN        NaN        NaN
#
#          Volume
# 0           NaN
# 1     8953200.0
# 2     4909200.0
# 3     3739200.0
# 4           NaN
# ...         ...
# 3648  3536400.0
# 3649  3378300.0
# 3650  4266900.0
# 3651        NaN
# 3652        NaN
#
# [3653 rows x 7 columns]

# %%
financial_metrics = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
for metric in financial_metrics:
    nee_merged[metric].interpolate(method='linear', inplace=True)

nee_merged.bfill(inplace=True)
nee_merged
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-01  17.497499  17.642500  17.452499  17.629999  13.064059
# 1    2013-01-02  17.497499  17.642500  17.452499  17.629999  13.064059
# 2    2013-01-03  17.650000  17.707500  17.582500  17.632500  13.065911
# 3    2013-01-04  17.660000  17.737499  17.612499  17.719999  13.130745
# 4    2013-01-05  17.677500  17.736666  17.606666  17.692500  13.110370
# ...         ...        ...        ...        ...        ...        ...
# 3648 2022-12-28  84.199997  84.540001  82.980003  83.160004  80.142830
# 3649 2022-12-29  83.730003  84.690002  83.489998  84.080002  81.029457
# 3650 2022-12-30  83.949997  84.019997  82.480003  83.599998  80.566872
# 3651 2022-12-31  83.949997  84.019997  82.480003  83.599998  80.566872
# 3652 2023-01-01  83.949997  84.019997  82.480003  83.599998  80.566872
#
#             Volume
# 0     8.953200e+06
# 1     8.953200e+06
# 2     4.909200e+06
# 3     3.739200e+06
# 4     4.352267e+06
# ...            ...
# 3648  3.536400e+06
# 3649  3.378300e+06
# 3650  4.266900e+06
# 3651  4.266900e+06
# 3652  4.266900e+06
#
# [3653 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 7))
plt.plot(nee_merged['Close'], label='Close Price', color='blue')
plt.title('NextEra Energy Inc Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

data = nee_merged[['Close']].values

scaler = MinMaxScaler(feature_range=(0,1))
data_scaled = scaler.fit_transform(data)

def create_sequences(data, sequence_length):
    xs, ys = [], []
    for i in range(len(data)-sequence_length):
        x = data[i:(i+sequence_length)]
        y = data[i+sequence_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

sequence_length = 10
X, y = create_sequences(data_scaled, sequence_length)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3278, 10, 1)
# (365, 10, 1)
# (3278, 1)
# (365, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Dropout, BatchNormalization, Bidirectional, TimeDistributed, Flatten

model = Sequential()

model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1],X_train.shape[2]), padding='same'))
model.add(MaxPooling1D(pool_size=1, padding='same'))

# model.add((Flatten()))

# model.add(BatchNormalization())
# model.add(MaxPooling1D(pool_size=1, padding='same'))
model.add(LSTM(units=64, return_sequences=False, activation='tanh'))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mean_absolute_error'])

# Model summary to see the architecture
model.summary()
# Out:
# C:\Users\Timch\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)                    │ (None, 10, 32)              │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 10, 32)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25,025 (97.75 KB)
#  Trainable params: 25,025 (97.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, validation_split=0.1)
# Out:
# Epoch 1/50
# 47/47 - 3s - 72ms/step - loss: 0.0131 - mean_absolute_error: 0.0689 - val_loss: 3.7929e-04 - val_mean_absolute_error: 0.0160
# Epoch 2/50
# 47/47 - 0s - 6ms/step - loss: 1.9490e-04 - mean_absolute_error: 0.0088 - val_loss: 3.6249e-04 - val_mean_absolute_error: 0.0153
# Epoch 3/50
# 47/47 - 0s - 6ms/step - loss: 1.4359e-04 - mean_absolute_error: 0.0068 - val_loss: 4.0354e-04 - val_mean_absolute_error: 0.0161
# Epoch 4/50
# 47/47 - 0s - 6ms/step - loss: 1.3951e-04 - mean_absolute_error: 0.0066 - val_loss: 4.3126e-04 - val_mean_absolute_error: 0.0167
# Epoch 5/50
# 47/47 - 0s - 7ms/step - loss: 1.4200e-04 - mean_absolute_error: 0.0067 - val_loss: 3.4846e-04 - val_mean_absolute_error: 0.0150
# Epoch 6/50
# 47/47 - 0s - 7ms/step - loss: 1.3504e-04 - mean_absolute_error: 0.0064 - val_loss: 4.1137e-04 - val_mean_absolute_error: 0.0163
# Epoch 7/50
# 47/47 - 0s - 7ms/step - loss: 1.3792e-04 - mean_absolute_error: 0.0066 - val_loss: 3.3979e-04 - val_mean_absolute_error: 0.0149
# Epoch 8/50
# 47/47 - 0s - 7ms/step - loss: 1.3399e-04 - mean_absolute_error: 0.0064 - val_loss: 3.4268e-04 - val_mean_absolute_error: 0.0149
# Epoch 9/50
# 47/47 - 0s - 6ms/step - loss: 1.5788e-04 - mean_absolute_error: 0.0069 - val_loss: 3.9902e-04 - val_mean_absolute_error: 0.0160
# Epoch 10/50
# 47/47 - 0s - 7ms/step - loss: 1.3479e-04 - mean_absolute_error: 0.0065 - val_loss: 3.5884e-04 - val_mean_absolute_error: 0.0152
# Epoch 11/50
# 47/47 - 0s - 10ms/step - loss: 1.3546e-04 - mean_absolute_error: 0.0065 - val_loss: 4.6998e-04 - val_mean_absolute_error: 0.0173
# Epoch 12/50
# 47/47 - 0s - 7ms/step - loss: 1.4817e-04 - mean_absolute_error: 0.0063 - val_loss: 4.2790e-04 - val_mean_absolute_error: 0.0165
# Epoch 13/50
# 47/47 - 0s - 7ms/step - loss: 1.4664e-04 - mean_absolute_error: 0.0071 - val_loss: 5.2133e-04 - val_mean_absolute_error: 0.0183
# Epoch 14/50
# 47/47 - 0s - 9ms/step - loss: 1.3594e-04 - mean_absolute_error: 0.0066 - val_loss: 3.0886e-04 - val_mean_absolute_error: 0.0140
# Epoch 15/50
# 47/47 - 0s - 8ms/step - loss: 1.2291e-04 - mean_absolute_error: 0.0061 - val_loss: 3.3115e-04 - val_mean_absolute_error: 0.0146
# Epoch 16/50
# 47/47 - 0s - 8ms/step - loss: 1.2704e-04 - mean_absolute_error: 0.0064 - val_loss: 3.0056e-04 - val_mean_absolute_error: 0.0138
# Epoch 17/50
# 47/47 - 0s - 9ms/step - loss: 1.2113e-04 - mean_absolute_error: 0.0062 - val_loss: 5.6534e-04 - val_mean_absolute_error: 0.0193
# Epoch 18/50
# 47/47 - 0s - 9ms/step - loss: 1.3658e-04 - mean_absolute_error: 0.0065 - val_loss: 6.9958e-04 - val_mean_absolute_error: 0.0229
# Epoch 19/50
# 47/47 - 0s - 8ms/step - loss: 1.5609e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9041e-04 - val_mean_absolute_error: 0.0136
# Epoch 20/50
# 47/47 - 0s - 7ms/step - loss: 1.3165e-04 - mean_absolute_error: 0.0066 - val_loss: 5.7204e-04 - val_mean_absolute_error: 0.0191
# Epoch 21/50
# 47/47 - 0s - 7ms/step - loss: 1.2038e-04 - mean_absolute_error: 0.0063 - val_loss: 3.5082e-04 - val_mean_absolute_error: 0.0149
# Epoch 22/50
# 47/47 - 0s - 6ms/step - loss: 1.1290e-04 - mean_absolute_error: 0.0060 - val_loss: 2.6343e-04 - val_mean_absolute_error: 0.0129
# Epoch 23/50
# 47/47 - 0s - 6ms/step - loss: 1.2331e-04 - mean_absolute_error: 0.0065 - val_loss: 4.6864e-04 - val_mean_absolute_error: 0.0173
# Epoch 24/50
# 47/47 - 0s - 8ms/step - loss: 1.4131e-04 - mean_absolute_error: 0.0073 - val_loss: 2.5353e-04 - val_mean_absolute_error: 0.0125
# Epoch 25/50
# 47/47 - 0s - 7ms/step - loss: 1.0596e-04 - mean_absolute_error: 0.0058 - val_loss: 2.4452e-04 - val_mean_absolute_error: 0.0123
# Epoch 26/50
# 47/47 - 0s - 6ms/step - loss: 1.0978e-04 - mean_absolute_error: 0.0059 - val_loss: 3.5389e-04 - val_mean_absolute_error: 0.0154
# Epoch 27/50
# 47/47 - 0s - 9ms/step - loss: 1.0504e-04 - mean_absolute_error: 0.0059 - val_loss: 2.6816e-04 - val_mean_absolute_error: 0.0128
# Epoch 28/50
# 47/47 - 0s - 7ms/step - loss: 1.1792e-04 - mean_absolute_error: 0.0062 - val_loss: 2.8315e-04 - val_mean_absolute_error: 0.0131
# Epoch 29/50
# 47/47 - 0s - 7ms/step - loss: 9.8183e-05 - mean_absolute_error: 0.0057 - val_loss: 3.5979e-04 - val_mean_absolute_error: 0.0157
# Epoch 30/50
# 47/47 - 0s - 7ms/step - loss: 9.5703e-05 - mean_absolute_error: 0.0055 - val_loss: 2.2410e-04 - val_mean_absolute_error: 0.0116
# Epoch 31/50
# 47/47 - 0s - 6ms/step - loss: 9.9724e-05 - mean_absolute_error: 0.0057 - val_loss: 2.7726e-04 - val_mean_absolute_error: 0.0136
# Epoch 32/50
# 47/47 - 0s - 6ms/step - loss: 9.8739e-05 - mean_absolute_error: 0.0057 - val_loss: 2.5502e-04 - val_mean_absolute_error: 0.0130
# Epoch 33/50
# 47/47 - 0s - 8ms/step - loss: 9.2001e-05 - mean_absolute_error: 0.0054 - val_loss: 2.0233e-04 - val_mean_absolute_error: 0.0112
# Epoch 34/50
# 47/47 - 0s - 6ms/step - loss: 9.2931e-05 - mean_absolute_error: 0.0057 - val_loss: 2.2840e-04 - val_mean_absolute_error: 0.0115
# Epoch 35/50
# 47/47 - 0s - 8ms/step - loss: 9.1293e-05 - mean_absolute_error: 0.0055 - val_loss: 1.8801e-04 - val_mean_absolute_error: 0.0105
# Epoch 36/50
# 47/47 - 0s - 8ms/step - loss: 9.4104e-05 - mean_absolute_error: 0.0057 - val_loss: 1.9293e-04 - val_mean_absolute_error: 0.0109
# Epoch 37/50
# 47/47 - 0s - 7ms/step - loss: 9.7470e-05 - mean_absolute_error: 0.0058 - val_loss: 1.8220e-04 - val_mean_absolute_error: 0.0104
# Epoch 38/50
# 47/47 - 0s - 7ms/step - loss: 8.5731e-05 - mean_absolute_error: 0.0053 - val_loss: 2.0015e-04 - val_mean_absolute_error: 0.0113
# Epoch 39/50
# 47/47 - 0s - 7ms/step - loss: 8.2841e-05 - mean_absolute_error: 0.0051 - val_loss: 5.2859e-04 - val_mean_absolute_error: 0.0189
# Epoch 40/50
# 47/47 - 0s - 7ms/step - loss: 8.3335e-05 - mean_absolute_error: 0.0052 - val_loss: 1.9380e-04 - val_mean_absolute_error: 0.0112
# Epoch 41/50
# 47/47 - 0s - 6ms/step - loss: 8.3961e-05 - mean_absolute_error: 0.0052 - val_loss: 1.6434e-04 - val_mean_absolute_error: 0.0096
# Epoch 42/50
# 47/47 - 0s - 7ms/step - loss: 7.8896e-05 - mean_absolute_error: 0.0050 - val_loss: 2.1801e-04 - val_mean_absolute_error: 0.0123
# Epoch 43/50
# 47/47 - 0s - 9ms/step - loss: 8.6330e-05 - mean_absolute_error: 0.0054 - val_loss: 1.7369e-04 - val_mean_absolute_error: 0.0104
# Epoch 44/50
# 47/47 - 0s - 7ms/step - loss: 8.7249e-05 - mean_absolute_error: 0.0055 - val_loss: 3.8329e-04 - val_mean_absolute_error: 0.0157
# Epoch 45/50
# 47/47 - 0s - 7ms/step - loss: 8.0957e-05 - mean_absolute_error: 0.0051 - val_loss: 1.8366e-04 - val_mean_absolute_error: 0.0110
# Epoch 46/50
# 47/47 - 0s - 7ms/step - loss: 7.1939e-05 - mean_absolute_error: 0.0046 - val_loss: 1.6817e-04 - val_mean_absolute_error: 0.0095
# Epoch 47/50
# 47/47 - 0s - 7ms/step - loss: 6.8984e-05 - mean_absolute_error: 0.0046 - val_loss: 1.5956e-04 - val_mean_absolute_error: 0.0093
# Epoch 48/50
# 47/47 - 0s - 7ms/step - loss: 7.4522e-05 - mean_absolute_error: 0.0046 - val_loss: 6.5457e-04 - val_mean_absolute_error: 0.0239
# Epoch 49/50
# 47/47 - 0s - 6ms/step - loss: 9.2720e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3403e-04 - val_mean_absolute_error: 0.0086
# Epoch 50/50
# 47/47 - 0s - 6ms/step - loss: 7.3951e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3076e-04 - val_mean_absolute_error: 0.0085

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training Loss vs. Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred_actual = scaler.inverse_transform(train_pred)
train_actual = scaler.inverse_transform(y_train)
test_pred_actual = scaler.inverse_transform(test_pred)
test_actual = scaler.inverse_transform(y_test)

train_rmse = sqrt(mean_squared_error(train_actual, train_pred_actual))
train_mae = mean_absolute_error(train_actual, train_pred_actual)
train_mape = np.mean(np.abs((train_actual - train_pred_actual) / train_actual)) * 100

test_rmse = sqrt(mean_squared_error(test_actual, test_pred_actual))
test_mae = mean_absolute_error(test_actual, test_pred_actual)
test_mape = np.mean(np.abs((test_actual - test_pred_actual) / test_actual)) * 100

print('Train RMSE:', train_rmse)
print('Train MAE:', train_mae)
print('Train MAPE:', train_mape)
print('Test RMSE:', test_rmse)
print('Test MAE:', test_mae)
print('Test MAPE:', test_mape)
# Out:
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train RMSE: 0.6351838819892563
# Train MAE: 0.35146771675933797
# Train MAPE: 0.8172077859124247
# Test RMSE: 1.407644976088501
# Test MAE: 1.002755068426263
# Test MAPE: 1.265047915537949

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(train_actual, label='Actual')
plt.plot(train_pred_actual, label='Predicted')
plt.title('Training Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()

plt.subplot(1,2,2)
plt.plot(test_actual, label='Actual')
plt.plot(test_pred_actual, label='Predicted')
plt.title('Testing Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

train_time = range(len(train_actual))
test_time = range(len(train_actual), len(train_actual) + len(test_actual))

plt.figure(figsize=(15, 7))
plt.plot(train_time, train_actual, label='Actual Train', color='blue')
plt.plot(train_time, train_pred_actual, label='Predicted Train', color='orange', alpha=0.7)
plt.plot(test_time, test_actual, label='Actual Test', color='green')
plt.plot(test_time, test_pred_actual, label='Predicted Test', color='red', alpha=0.7)

plt.title('Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
